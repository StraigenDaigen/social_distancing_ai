# %%
# %cd D:/Universidad/Computer_Vision_UAO/Proyecto_de_curso_CVwDP/od_distanciamiento_social
# Out:
# D:\Universidad\Computer_Vision_UAO\Proyecto_de_curso_CVwDP\od_distanciamiento_social

# %%
import tensorflow as tf
print(tf.__version__)
import keras
print(keras.__version__)
# Out:
# C:\Users\steven\anaconda3\envs\deepia\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\steven\anaconda3\envs\deepia\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\steven\anaconda3\envs\deepia\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\steven\anaconda3\envs\deepia\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\steven\anaconda3\envs\deepia\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\steven\anaconda3\envs\deepia\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\steven\anaconda3\envs\deepia\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\steven\anaconda3\envs\deepia\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\steven\anaconda3\envs\deepia\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\steven\anaconda3\envs\deepia\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\steven\anaconda3\envs\deepia\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\steven\anaconda3\envs\deepia\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# 1.14.0
# 2.2.4
# Using TensorFlow backend.

# %% [markdown]
# **Instalar librerias y repositorio de keras retinanet**

# %%
# !pip install imutils
# !pip install beautifulsoup4
# !git clone https://github.com/fizyr/keras-retinanet
# Out:
# Requirement already satisfied: imutils in c:\users\steven\anaconda3\envs\deepia\lib\site-packages (0.5.4)
# Requirement already satisfied: beautifulsoup4 in c:\users\steven\anaconda3\envs\deepia\lib\site-packages (4.9.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\steven\anaconda3\envs\deepia\lib\site-packages (from beautifulsoup4) (2.2.1)
# fatal: destination path 'keras-retinanet' already exists and is not an empty directory.

# %% [markdown]
# **Instalar keras retinanet**

# %%
# %cd D:\Universidad\Computer_Vision_UAO\Proyecto_de_curso_CVwDP\od_distanciamiento_social\keras-retinanet
# !git checkout 42068ef9e406602d92a1afe2ee7d470f7e9860df
# !python setup.py install
# Out:
# D:\Universidad\Computer_Vision_UAO\Proyecto_de_curso_CVwDP\od_distanciamiento_social\keras-retinanet
# HEAD is now at 42068ef Merge pull request #621 from borakrc/fix-anchor-boxes-not-shown
# running install
# running bdist_egg
# running egg_info
# writing keras_retinanet.egg-info\PKG-INFO
# writing dependency_links to keras_retinanet.egg-info\dependency_links.txt
# writing entry points to keras_retinanet.egg-info\entry_points.txt
# writing requirements to keras_retinanet.egg-info\requires.txt
# writing top-level names to keras_retinanet.egg-info\top_level.txt
# reading manifest file 'keras_retinanet.egg-info\SOURCES.txt'
# writing manifest file 'keras_retinanet.egg-info\SOURCES.txt'
# installing library code to build\bdist.win-amd64\egg
# running install_lib
# running build_py
# running build_ext
# skipping 'keras_retinanet/utils\compute_overlap.c' Cython extension (up-to-date)
# creating build\bdist.win-amd64\egg
# creating build\bdist.win-amd64\egg\keras_retinanet
# creating build\bdist.win-amd64\egg\keras_retinanet\backend
# copying build\lib.win-amd64-3.7\keras_retinanet\backend\cntk_backend.py -> build\bdist.win-amd64\egg\keras_retinanet\backend
# copying build\lib.win-amd64-3.7\keras_retinanet\backend\common.py -> build\bdist.win-amd64\egg\keras_retinanet\backend
# copying build\lib.win-amd64-3.7\keras_retinanet\backend\dynamic.py -> build\bdist.win-amd64\egg\keras_retinanet\backend
# copying build\lib.win-amd64-3.7\keras_retinanet\backend\tensorflow_backend.py -> build\bdist.win-amd64\egg\keras_retinanet\backend
# copying build\lib.win-amd64-3.7\keras_retinanet\backend\theano_backend.py -> build\bdist.win-amd64\egg\keras_retinanet\backend
# copying build\lib.win-amd64-3.7\keras_retinanet\backend\__init__.py -> build\bdist.win-amd64\egg\keras_retinanet\backend
# creating build\bdist.win-amd64\egg\keras_retinanet\bin
# copying build\lib.win-amd64-3.7\keras_retinanet\bin\convert_model.py -> build\bdist.win-amd64\egg\keras_retinanet\bin
# copying build\lib.win-amd64-3.7\keras_retinanet\bin\debug.py -> build\bdist.win-amd64\egg\keras_retinanet\bin
# copying build\lib.win-amd64-3.7\keras_retinanet\bin\evaluate.py -> build\bdist.win-amd64\egg\keras_retinanet\bin
# copying build\lib.win-amd64-3.7\keras_retinanet\bin\train.py -> build\bdist.win-amd64\egg\keras_retinanet\bin
# copying build\lib.win-amd64-3.7\keras_retinanet\bin\__init__.py -> build\bdist.win-amd64\egg\keras_retinanet\bin
# creating build\bdist.win-amd64\egg\keras_retinanet\callbacks
# copying build\lib.win-amd64-3.7\keras_retinanet\callbacks\coco.py -> build\bdist.win-amd64\egg\keras_retinanet\callbacks
# copying build\lib.win-amd64-3.7\keras_retinanet\callbacks\common.py -> build\bdist.win-amd64\egg\keras_retinanet\callbacks
# copying build\lib.win-amd64-3.7\keras_retinanet\callbacks\eval.py -> build\bdist.win-amd64\egg\keras_retinanet\callbacks
# copying build\lib.win-amd64-3.7\keras_retinanet\callbacks\__init__.py -> build\bdist.win-amd64\egg\keras_retinanet\callbacks
# copying build\lib.win-amd64-3.7\keras_retinanet\initializers.py -> build\bdist.win-amd64\egg\keras_retinanet
# creating build\bdist.win-amd64\egg\keras_retinanet\layers
# copying build\lib.win-amd64-3.7\keras_retinanet\layers\filter_detections.py -> build\bdist.win-amd64\egg\keras_retinanet\layers
# copying build\lib.win-amd64-3.7\keras_retinanet\layers\_misc.py -> build\bdist.win-amd64\egg\keras_retinanet\layers
# copying build\lib.win-amd64-3.7\keras_retinanet\layers\__init__.py -> build\bdist.win-amd64\egg\keras_retinanet\layers
# copying build\lib.win-amd64-3.7\keras_retinanet\losses.py -> build\bdist.win-amd64\egg\keras_retinanet
# creating build\bdist.win-amd64\egg\keras_retinanet\models
# copying build\lib.win-amd64-3.7\keras_retinanet\models\densenet.py -> build\bdist.win-amd64\egg\keras_retinanet\models
# copying build\lib.win-amd64-3.7\keras_retinanet\models\mobilenet.py -> build\bdist.win-amd64\egg\keras_retinanet\models
# copying build\lib.win-amd64-3.7\keras_retinanet\models\resnet.py -> build\bdist.win-amd64\egg\keras_retinanet\models
# copying build\lib.win-amd64-3.7\keras_retinanet\models\retinanet.py -> build\bdist.win-amd64\egg\keras_retinanet\models
# copying build\lib.win-amd64-3.7\keras_retinanet\models\vgg.py -> build\bdist.win-amd64\egg\keras_retinanet\models
# copying build\lib.win-amd64-3.7\keras_retinanet\models\__init__.py -> build\bdist.win-amd64\egg\keras_retinanet\models
# creating build\bdist.win-amd64\egg\keras_retinanet\preprocessing
# copying build\lib.win-amd64-3.7\keras_retinanet\preprocessing\coco.py -> build\bdist.win-amd64\egg\keras_retinanet\preprocessing
# copying build\lib.win-amd64-3.7\keras_retinanet\preprocessing\csv_generator.py -> build\bdist.win-amd64\egg\keras_retinanet\preprocessing
# copying build\lib.win-amd64-3.7\keras_retinanet\preprocessing\generator.py -> build\bdist.win-amd64\egg\keras_retinanet\preprocessing
# copying build\lib.win-amd64-3.7\keras_retinanet\preprocessing\kitti.py -> build\bdist.win-amd64\egg\keras_retinanet\preprocessing
# copying build\lib.win-amd64-3.7\keras_retinanet\preprocessing\open_images.py -> build\bdist.win-amd64\egg\keras_retinanet\preprocessing
# copying build\lib.win-amd64-3.7\keras_retinanet\preprocessing\pascal_voc.py -> build\bdist.win-amd64\egg\keras_retinanet\preprocessing
# copying build\lib.win-amd64-3.7\keras_retinanet\preprocessing\__init__.py -> build\bdist.win-amd64\egg\keras_retinanet\preprocessing
# creating build\bdist.win-amd64\egg\keras_retinanet\utils
# copying build\lib.win-amd64-3.7\keras_retinanet\utils\anchors.py -> build\bdist.win-amd64\egg\keras_retinanet\utils
# copying build\lib.win-amd64-3.7\keras_retinanet\utils\coco_eval.py -> build\bdist.win-amd64\egg\keras_retinanet\utils
# copying build\lib.win-amd64-3.7\keras_retinanet\utils\colors.py -> build\bdist.win-amd64\egg\keras_retinanet\utils
# copying build\lib.win-amd64-3.7\keras_retinanet\utils\compute_overlap.cp37-win_amd64.pyd -> build\bdist.win-amd64\egg\keras_retinanet\utils
# copying build\lib.win-amd64-3.7\keras_retinanet\utils\eval.py -> build\bdist.win-amd64\egg\keras_retinanet\utils
# copying build\lib.win-amd64-3.7\keras_retinanet\utils\image.py -> build\bdist.win-amd64\egg\keras_retinanet\utils
# copying build\lib.win-amd64-3.7\keras_retinanet\utils\keras_version.py -> build\bdist.win-amd64\egg\keras_retinanet\utils
# copying build\lib.win-amd64-3.7\keras_retinanet\utils\model.py -> build\bdist.win-amd64\egg\keras_retinanet\utils
# copying build\lib.win-amd64-3.7\keras_retinanet\utils\transform.py -> build\bdist.win-amd64\egg\keras_retinanet\utils
# copying build\lib.win-amd64-3.7\keras_retinanet\utils\visualization.py -> build\bdist.win-amd64\egg\keras_retinanet\utils
# copying build\lib.win-amd64-3.7\keras_retinanet\utils\__init__.py -> build\bdist.win-amd64\egg\keras_retinanet\utils
# copying build\lib.win-amd64-3.7\keras_retinanet\__init__.py -> build\bdist.win-amd64\egg\keras_retinanet
# creating build\bdist.win-amd64\egg\tests
# creating build\bdist.win-amd64\egg\tests\backend
# copying build\lib.win-amd64-3.7\tests\backend\test_common.py -> build\bdist.win-amd64\egg\tests\backend
# copying build\lib.win-amd64-3.7\tests\backend\__init__.py -> build\bdist.win-amd64\egg\tests\backend
# creating build\bdist.win-amd64\egg\tests\layers
# copying build\lib.win-amd64-3.7\tests\layers\test_filter_detections.py -> build\bdist.win-amd64\egg\tests\layers
# copying build\lib.win-amd64-3.7\tests\layers\test_misc.py -> build\bdist.win-amd64\egg\tests\layers
# copying build\lib.win-amd64-3.7\tests\layers\__init__.py -> build\bdist.win-amd64\egg\tests\layers
# creating build\bdist.win-amd64\egg\tests\models
# copying build\lib.win-amd64-3.7\tests\models\test_densenet.py -> build\bdist.win-amd64\egg\tests\models
# copying build\lib.win-amd64-3.7\tests\models\test_mobilenet.py -> build\bdist.win-amd64\egg\tests\models
# copying build\lib.win-amd64-3.7\tests\models\__init__.py -> build\bdist.win-amd64\egg\tests\models
# creating build\bdist.win-amd64\egg\tests\preprocessing
# copying build\lib.win-amd64-3.7\tests\preprocessing\test_csv_generator.py -> build\bdist.win-amd64\egg\tests\preprocessing
# copying build\lib.win-amd64-3.7\tests\preprocessing\test_generator.py -> build\bdist.win-amd64\egg\tests\preprocessing
# copying build\lib.win-amd64-3.7\tests\preprocessing\__init__.py -> build\bdist.win-amd64\egg\tests\preprocessing
# copying build\lib.win-amd64-3.7\tests\test_losses.py -> build\bdist.win-amd64\egg\tests
# creating build\bdist.win-amd64\egg\tests\utils
# copying build\lib.win-amd64-3.7\tests\utils\test_transform.py -> build\bdist.win-amd64\egg\tests\utils
# copying build\lib.win-amd64-3.7\tests\utils\__init__.py -> build\bdist.win-amd64\egg\tests\utils
# copying build\lib.win-amd64-3.7\tests\__init__.py -> build\bdist.win-amd64\egg\tests
# byte-compiling build\bdist.win-amd64\egg\keras_retinanet\backend\cntk_backend.py to cntk_backend.cpython-37.pyc
# byte-compiling build\bdist.win-amd64\egg\keras_retinanet\backend\common.py to common.cpython-37.pyc
# byte-compiling build\bdist.win-amd64\egg\keras_retinanet\backend\dynamic.py to dynamic.cpython-37.pyc
# byte-compiling build\bdist.win-amd64\egg\keras_retinanet\backend\tensorflow_backend.py to tensorflow_backend.cpython-37.pyc
# byte-compiling build\bdist.win-amd64\egg\keras_retinanet\backend\theano_backend.py to theano_backend.cpython-37.pyc
# byte-compiling build\bdist.win-amd64\egg\keras_retinanet\backend\__init__.py to __init__.cpython-37.pyc
# byte-compiling build\bdist.win-amd64\egg\keras_retinanet\bin\convert_model.py to convert_model.cpython-37.pyc
# byte-compiling build\bdist.win-amd64\egg\keras_retinanet\bin\debug.py to debug.cpython-37.pyc
# byte-compiling build\bdist.win-amd64\egg\keras_retinanet\bin\evaluate.py to evaluate.cpython-37.pyc
# byte-compiling build\bdist.win-amd64\egg\keras_retinanet\bin\train.py to train.cpython-37.pyc
# byte-compiling build\bdist.win-amd64\egg\keras_retinanet\bin\__init__.py to __init__.cpython-37.pyc
# byte-compiling build\bdist.win-amd64\egg\keras_retinanet\callbacks\coco.py to coco.cpython-37.pyc
# byte-compiling build\bdist.win-amd64\egg\keras_retinanet\callbacks\common.py to common.cpython-37.pyc
# byte-compiling build\bdist.win-amd64\egg\keras_retinanet\callbacks\eval.py to eval.cpython-37.pyc
# byte-compiling build\bdist.win-amd64\egg\keras_retinanet\callbacks\__init__.py to __init__.cpython-37.pyc
# byte-compiling build\bdist.win-amd64\egg\keras_retinanet\initializers.py to initializers.cpython-37.pyc
# byte-compiling build\bdist.win-amd64\egg\keras_retinanet\layers\filter_detections.py to filter_detections.cpython-37.pyc
# byte-compiling build\bdist.win-amd64\egg\keras_retinanet\layers\_misc.py to _misc.cpython-37.pyc
# byte-compiling build\bdist.win-amd64\egg\keras_retinanet\layers\__init__.py to __init__.cpython-37.pyc
# byte-compiling build\bdist.win-amd64\egg\keras_retinanet\losses.py to losses.cpython-37.pyc
# byte-compiling build\bdist.win-amd64\egg\keras_retinanet\models\densenet.py to densenet.cpython-37.pyc
# byte-compiling build\bdist.win-amd64\egg\keras_retinanet\models\mobilenet.py to mobilenet.cpython-37.pyc
# byte-compiling build\bdist.win-amd64\egg\keras_retinanet\models\resnet.py to resnet.cpython-37.pyc
# byte-compiling build\bdist.win-amd64\egg\keras_retinanet\models\retinanet.py to retinanet.cpython-37.pyc
# byte-compiling build\bdist.win-amd64\egg\keras_retinanet\models\vgg.py to vgg.cpython-37.pyc
# byte-compiling build\bdist.win-amd64\egg\keras_retinanet\models\__init__.py to __init__.cpython-37.pyc
# byte-compiling build\bdist.win-amd64\egg\keras_retinanet\preprocessing\coco.py to coco.cpython-37.pyc
# byte-compiling build\bdist.win-amd64\egg\keras_retinanet\preprocessing\csv_generator.py to csv_generator.cpython-37.pyc
# byte-compiling build\bdist.win-amd64\egg\keras_retinanet\preprocessing\generator.py to generator.cpython-37.pyc
# byte-compiling build\bdist.win-amd64\egg\keras_retinanet\preprocessing\kitti.py to kitti.cpython-37.pyc
# byte-compiling build\bdist.win-amd64\egg\keras_retinanet\preprocessing\open_images.py to open_images.cpython-37.pyc
# byte-compiling build\bdist.win-amd64\egg\keras_retinanet\preprocessing\pascal_voc.py to pascal_voc.cpython-37.pyc
# byte-compiling build\bdist.win-amd64\egg\keras_retinanet\preprocessing\__init__.py to __init__.cpython-37.pyc
# byte-compiling build\bdist.win-amd64\egg\keras_retinanet\utils\anchors.py to anchors.cpython-37.pyc
# byte-compiling build\bdist.win-amd64\egg\keras_retinanet\utils\coco_eval.py to coco_eval.cpython-37.pyc
# byte-compiling build\bdist.win-amd64\egg\keras_retinanet\utils\colors.py to colors.cpython-37.pyc
# byte-compiling build\bdist.win-amd64\egg\keras_retinanet\utils\eval.py to eval.cpython-37.pyc
# byte-compiling build\bdist.win-amd64\egg\keras_retinanet\utils\image.py to image.cpython-37.pyc
# byte-compiling build\bdist.win-amd64\egg\keras_retinanet\utils\keras_version.py to keras_version.cpython-37.pyc
# byte-compiling build\bdist.win-amd64\egg\keras_retinanet\utils\model.py to model.cpython-37.pyc
# byte-compiling build\bdist.win-amd64\egg\keras_retinanet\utils\transform.py to transform.cpython-37.pyc
# byte-compiling build\bdist.win-amd64\egg\keras_retinanet\utils\visualization.py to visualization.cpython-37.pyc
# byte-compiling build\bdist.win-amd64\egg\keras_retinanet\utils\__init__.py to __init__.cpython-37.pyc
# byte-compiling build\bdist.win-amd64\egg\keras_retinanet\__init__.py to __init__.cpython-37.pyc
# byte-compiling build\bdist.win-amd64\egg\tests\backend\test_common.py to test_common.cpython-37.pyc
# byte-compiling build\bdist.win-amd64\egg\tests\backend\__init__.py to __init__.cpython-37.pyc
# byte-compiling build\bdist.win-amd64\egg\tests\layers\test_filter_detections.py to test_filter_detections.cpython-37.pyc
# byte-compiling build\bdist.win-amd64\egg\tests\layers\test_misc.py to test_misc.cpython-37.pyc
# byte-compiling build\bdist.win-amd64\egg\tests\layers\__init__.py to __init__.cpython-37.pyc
# byte-compiling build\bdist.win-amd64\egg\tests\models\test_densenet.py to test_densenet.cpython-37.pyc
# byte-compiling build\bdist.win-amd64\egg\tests\models\test_mobilenet.py to test_mobilenet.cpython-37.pyc
# byte-compiling build\bdist.win-amd64\egg\tests\models\__init__.py to __init__.cpython-37.pyc
# byte-compiling build\bdist.win-amd64\egg\tests\preprocessing\test_csv_generator.py to test_csv_generator.cpython-37.pyc
# byte-compiling build\bdist.win-amd64\egg\tests\preprocessing\test_generator.py to test_generator.cpython-37.pyc
# byte-compiling build\bdist.win-amd64\egg\tests\preprocessing\__init__.py to __init__.cpython-37.pyc
# byte-compiling build\bdist.win-amd64\egg\tests\test_losses.py to test_losses.cpython-37.pyc
# byte-compiling build\bdist.win-amd64\egg\tests\utils\test_transform.py to test_transform.cpython-37.pyc
# byte-compiling build\bdist.win-amd64\egg\tests\utils\__init__.py to __init__.cpython-37.pyc
# byte-compiling build\bdist.win-amd64\egg\tests\__init__.py to __init__.cpython-37.pyc
# creating stub loader for keras_retinanet\utils\compute_overlap.cp37-win_amd64.pyd
# byte-compiling build\bdist.win-amd64\egg\keras_retinanet\utils\compute_overlap.py to compute_overlap.cpython-37.pyc
# creating build\bdist.win-amd64\egg\EGG-INFO
# copying keras_retinanet.egg-info\PKG-INFO -> build\bdist.win-amd64\egg\EGG-INFO
# copying keras_retinanet.egg-info\SOURCES.txt -> build\bdist.win-amd64\egg\EGG-INFO
# copying keras_retinanet.egg-info\dependency_links.txt -> build\bdist.win-amd64\egg\EGG-INFO
# copying keras_retinanet.egg-info\entry_points.txt -> build\bdist.win-amd64\egg\EGG-INFO
# copying keras_retinanet.egg-info\requires.txt -> build\bdist.win-amd64\egg\EGG-INFO
# copying keras_retinanet.egg-info\top_level.txt -> build\bdist.win-amd64\egg\EGG-INFO
# writing build\bdist.win-amd64\egg\EGG-INFO\native_libs.txt
# creating 'dist\keras_retinanet-0.4.1-py3.7-win-amd64.egg' and adding 'build\bdist.win-amd64\egg' to it
# removing 'build\bdist.win-amd64\egg' (and everything under it)
# Processing keras_retinanet-0.4.1-py3.7-win-amd64.egg
# removing 'c:\users\steven\anaconda3\envs\deepia\lib\site-packages\keras_retinanet-0.4.1-py3.7-win-amd64.egg' (and everything under it)
# creating c:\users\steven\anaconda3\envs\deepia\lib\site-packages\keras_retinanet-0.4.1-py3.7-win-amd64.egg
# Extracting keras_retinanet-0.4.1-py3.7-win-amd64.egg to c:\users\steven\anaconda3\envs\deepia\lib\site-packages
# keras-retinanet 0.4.1 is already the active version in easy-install.pth
# Installing retinanet-convert-model-script.py script to C:\Users\steven\anaconda3\envs\deepia\Scripts
# Installing retinanet-convert-model.exe script to C:\Users\steven\anaconda3\envs\deepia\Scripts
# Installing retinanet-debug-script.py script to C:\Users\steven\anaconda3\envs\deepia\Scripts
# Installing retinanet-debug.exe script to C:\Users\steven\anaconda3\envs\deepia\Scripts
# Installing retinanet-evaluate-script.py script to C:\Users\steven\anaconda3\envs\deepia\Scripts
# Installing retinanet-evaluate.exe script to C:\Users\steven\anaconda3\envs\deepia\Scripts
# Installing retinanet-train-script.py script to C:\Users\steven\anaconda3\envs\deepia\Scripts
# Installing retinanet-train.exe script to C:\Users\steven\anaconda3\envs\deepia\Scripts
#
# Installed c:\users\steven\anaconda3\envs\deepia\lib\site-packages\keras_retinanet-0.4.1-py3.7-win-amd64.egg
# Processing dependencies for keras-retinanet==0.4.1
# Searching for Cython==0.29.22
# Best match: Cython 0.29.22
# Adding Cython 0.29.22 to easy-install.pth file
# Installing cygdb-script.py script to C:\Users\steven\anaconda3\envs\deepia\Scripts
# Installing cygdb.exe script to C:\Users\steven\anaconda3\envs\deepia\Scripts
# Installing cython-script.py script to C:\Users\steven\anaconda3\envs\deepia\Scripts
# Installing cython.exe script to C:\Users\steven\anaconda3\envs\deepia\Scripts
# Installing cythonize-script.py script to C:\Users\steven\anaconda3\envs\deepia\Scripts
# Installing cythonize.exe script to C:\Users\steven\anaconda3\envs\deepia\Scripts
#
# Using c:\users\steven\anaconda3\envs\deepia\lib\site-packages
# Searching for scipy==1.6.2
# Best match: scipy 1.6.2
# Adding scipy 1.6.2 to easy-install.pth file
#
# Using c:\users\steven\anaconda3\envs\deepia\lib\site-packages
# Searching for six==1.15.0
# Best match: six 1.15.0
# Adding six 1.15.0 to easy-install.pth file
#
# Using c:\users\steven\anaconda3\envs\deepia\lib\site-packages
# Searching for keras-resnet==0.2.0
# Best match: keras-resnet 0.2.0
# Processing keras_resnet-0.2.0-py3.7.egg
# keras-resnet 0.2.0 is already the active version in easy-install.pth
#
# Using c:\users\steven\anaconda3\envs\deepia\lib\site-packages\keras_resnet-0.2.0-py3.7.egg
# Searching for Keras==2.2.4
# Best match: Keras 2.2.4
# Adding Keras 2.2.4 to easy-install.pth file
#
# Using c:\users\steven\anaconda3\envs\deepia\lib\site-packages
# Searching for numpy==1.19.2
# Best match: numpy 1.19.2
# Adding numpy 1.19.2 to easy-install.pth file
# Installing f2py-script.py script to C:\Users\steven\anaconda3\envs\deepia\Scripts
# Installing f2py.exe script to C:\Users\steven\anaconda3\envs\deepia\Scripts
#
# Using c:\users\steven\anaconda3\envs\deepia\lib\site-packages
# Searching for Keras-Preprocessing==1.1.2
# Best match: Keras-Preprocessing 1.1.2
# Adding Keras-Preprocessing 1.1.2 to easy-install.pth file
#
# Using c:\users\steven\anaconda3\envs\deepia\lib\site-packages
# Searching for Keras-Applications==1.0.8
# Best match: Keras-Applications 1.0.8
# Adding Keras-Applications 1.0.8 to easy-install.pth file
#
# Using c:\users\steven\anaconda3\envs\deepia\lib\site-packages
# Searching for h5py==2.8.0
# Best match: h5py 2.8.0
# Adding h5py 2.8.0 to easy-install.pth file
#
# Using c:\users\steven\anaconda3\envs\deepia\lib\site-packages
# Searching for PyYAML==5.4.1
# Best match: PyYAML 5.4.1
# Adding PyYAML 5.4.1 to easy-install.pth file
#
# Using c:\users\steven\anaconda3\envs\deepia\lib\site-packages
# Finished processing dependencies for keras-retinanet==0.4.1
# zip_safe flag not set; analyzing archive contents...
# keras_retinanet.bin.__pycache__.convert_model.cpython-37: module references __file__
# keras_retinanet.bin.__pycache__.debug.cpython-37: module references __file__
# keras_retinanet.bin.__pycache__.evaluate.cpython-37: module references __file__
# keras_retinanet.bin.__pycache__.train.cpython-37: module references __file__
# keras_retinanet.utils.__pycache__.compute_overlap.cpython-37: module references __file__

# %% [markdown]
# **Probar que la instalación haya sido exitosa**

# %%
# %cd D:/Universidad/Computer_Vision_UAO/Proyecto_de_curso_CVwDP/od_distanciamiento_social/keras-retinanet/
# Out:
# D:\Universidad\Computer_Vision_UAO\Proyecto_de_curso_CVwDP\od_distanciamiento_social\keras-retinanet

# %%
# !retinanet-train
# Out:
# Using TensorFlow backend.
# C:\Users\steven\anaconda3\envs\deepia\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\steven\anaconda3\envs\deepia\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\steven\anaconda3\envs\deepia\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\steven\anaconda3\envs\deepia\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\steven\anaconda3\envs\deepia\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\steven\anaconda3\envs\deepia\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\steven\anaconda3\envs\deepia\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\steven\anaconda3\envs\deepia\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\steven\anaconda3\envs\deepia\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\steven\anaconda3\envs\deepia\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\steven\anaconda3\envs\deepia\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\steven\anaconda3\envs\deepia\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# usage: retinanet-train [-h]
#                        [--snapshot SNAPSHOT | --imagenet-weights | --weights WEIGHTS | --no-weights]
#                        [--backbone BACKBONE] [--batch-size BATCH_SIZE]
#                        [--gpu GPU] [--multi-gpu MULTI_GPU] [--multi-gpu-force]
#                        [--epochs EPOCHS] [--steps STEPS]
#                        [--snapshot-path SNAPSHOT_PATH]
#                        [--tensorboard-dir TENSORBOARD_DIR] [--no-snapshots]
#                        [--no-evaluation] [--freeze-backbone]
#                        [--random-transform] [--image-min-side IMAGE_MIN_SIDE]
#                        [--image-max-side IMAGE_MAX_SIDE]
#                        {coco,pascal,kitti,oid,csv} ...
# retinanet-train: error: the following arguments are required: dataset_type

# %% [markdown]
# **Se usará el mismo archivo de dataset de 10k imagenes que se usó en Faster RCNN**

# %%
from bs4 import BeautifulSoup
import os

dataset_path = "D:/Universidad/Computer_Vision_UAO/Proyecto_de_curso_CVwDP/od_distanciamiento_social/keras-retinanet/"

# Ruta de archivo con clases
CLASSES_CSV = os.path.sep.join([dataset_path, "retinanet_classes.csv"])

#Clases a usar 
CLASSES = ["Person"]
# write the classes to file
print("[INFO] clases a usar...")
csv = open(CLASSES_CSV, "w")
rows = [",".join([c, str(i)]) for (i, c) in enumerate(CLASSES)]
csv.write("\n".join(rows))
csv.close()
# Out:
# [INFO] clases a usar...

# %% [markdown]
# **Comprobar que se haya creado el archivo de clases, creando un CSV con la clase y un numero indicando la etiqueta asociada, en este caso como es solo una clase "Person", se adiciona la etiqueta "0"**

# %%
# %ls
# Out:
#  El volumen de la unidad D es Informacion
#  El n£mero de serie del volumen es: 3875-34A3
#
#  Directorio de D:\Universidad\Computer_Vision_UAO\Proyecto_de_curso_CVwDP\od_distanciamiento_social\keras-retinanet
#
# 27/03/2021  03:43 p.ÿm.    <DIR>          .
# 27/03/2021  03:43 p.ÿm.    <DIR>          ..
# 24/03/2021  10:53 p.ÿm.                57 .gitignore
# 24/03/2021  10:52 p.ÿm.               119 .gitmodules
# 24/03/2021  10:53 p.ÿm.               663 .travis.yml
# 27/03/2021  07:12 p.ÿm.    <DIR>          build
# 24/03/2021  10:53 p.ÿm.               849 CONTRIBUTORS.md
# 27/03/2021  07:12 p.ÿm.    <DIR>          dist
# 27/03/2021  01:52 p.ÿm.           470.005 entrenamiento1000.txt
# 24/03/2021  10:53 p.ÿm.    <DIR>          examples
# 24/03/2021  10:52 p.ÿm.    <DIR>          images
# 24/03/2021  10:53 p.ÿm.             1.362 ISSUE_TEMPLATE.md
# 24/03/2021  11:13 p.ÿm.    <DIR>          keras_retinanet
# 27/03/2021  08:29 p.ÿm.    <DIR>          keras_retinanet.egg-info
# 24/03/2021  10:52 p.ÿm.            11.558 LICENSE
# 27/03/2021  11:10 a.ÿm.         1.998.324 prueba_img.png
# 24/03/2021  10:53 p.ÿm.            16.198 README.md
# 24/03/2021  11:33 p.ÿm.       152.662.144 resnet50_coco_best_v2.1.0.h5
# 27/03/2021  08:29 p.ÿm.                 8 retinanet_classes.csv
# 27/03/2021  03:43 p.ÿm.    <DIR>          retinanet_snapshots
# 27/03/2021  11:08 a.ÿm.       146.107.264 retinanet_weights_person_original_colab.h5
# 24/03/2021  10:53 p.ÿm.               379 setup.cfg
# 24/03/2021  10:53 p.ÿm.             1.244 setup.py
# 24/03/2021  10:52 p.ÿm.    <DIR>          snapshots
# 27/03/2021  02:00 p.ÿm.           108.166 test1000.txt
# 24/03/2021  10:53 p.ÿm.    <DIR>          tests
#               15 archivos    301.378.340 bytes
#               11 dirs  338.854.387.712 bytes libres

# %% [markdown]
# **Descargar los pesos de la red que usara como backbone**

# %%
#%cd /gdrive/MyDrive/Especializaciones_TIC_UAO/Especializacion_IA/Computer_Vision/proyecto/
#!wget https://github.com/fizyr/keras-retinanet/releases/download/0.5.1/resnet50_coco_best_v2.1.0.h5

# %% [markdown]
# **entrenamiento**

# %%
# Opening a file
file = open("entrenamiento1000.txt","r")
Counter = 0
  
# Reading from file
Content = file.read()
CoList = Content.split("\n")
  
for i in CoList:
    if i:
        Counter += 1
          
print("La cantidad de anotaciones es:")
print(Counter)
# Out:
# La cantidad de anotaciones es:
# 3809

# %% [markdown]
# **De acuerdo al numero de anotaciones, calculamos el Step Per Epoch, como actualmente contamos con una GTX 850M como GPU, podemos disponer de 4GB de memoria de GPU, por ende, podremos procesar aproximadamente un batch size de 4 imagenes, por lo tanto, dividimos 3809  para redondear de Steps per epoch**

# %% [markdown]
# **Comenzar Entrenamiento**

# %%
# !mkdir retinanet_snapshots
# Out:
# Ya existe el subdirectorio o el archivo retinanet_snapshots.

# %%
batch_size=1
steps_per_epoch = Counter//batch_size
print(steps_per_epoch)
# Out:
# 3809

# %%
labels= D:/Universidad/Computer_Vision_UAO/Proyecto_de_curso_CVwDP/od_distanciamiento_social/keras-retinanet/retinanet_classes.csv
train_file_dir = D:/Universidad/Computer_Vision_UAO/Proyecto_de_curso_CVwDP/od_distanciamiento_social/keras-retinanet/entrenamiento1000.txt
model_train_dir= D:/Universidad/Computer_Vision_UAO/Proyecto_de_curso_CVwDP/od_distanciamiento_social/keras-retinanet/resnet50_coco_best_v2.1.0.h5
logs_dir= D:/Universidad/Computer_Vision_UAO/Proyecto_de_curso_CVwDP/od_distanciamiento_social/keras-retinanet/retinanet_snapshots
# Out:
#   File "<ipython-input-22-6bc8b84714ad>", line 1
#     labels= D:/Universidad/Computer_Vision_UAO/Proyecto_de_curso_CVwDP/od_distanciamiento_social/keras-retinanet/retinanet_classes.csv
#              ^
# SyntaxError: invalid syntax

# %%
# %cd D:/Universidad/Computer_Vision_UAO/Proyecto_de_curso_CVwDP/od_distanciamiento_social/keras-retinanet
#import tensorflow.compat.v1 as tf
#tf.disable_v2_behavior()
# !python setup.py build_ext --inplace
# !pip install keras-resnet
# !pip install .
# Out:
# D:\Universidad\Computer_Vision_UAO\Proyecto_de_curso_CVwDP\od_distanciamiento_social\keras-retinanet
# running build_ext
# skipping 'keras_retinanet/utils\compute_overlap.c' Cython extension (up-to-date)
# copying build\lib.win-amd64-3.7\keras_retinanet\utils\compute_overlap.cp37-win_amd64.pyd -> keras_retinanet\utils
# Collecting keras-resnet
#   Downloading keras-resnet-0.2.0.tar.gz (9.3 kB)
# Collecting keras>=2.2.4
#   Using cached Keras-2.4.3-py2.py3-none-any.whl (36 kB)
# Requirement already satisfied: numpy>=1.9.1 in c:\users\steven\anaconda3\envs\pruebas_ia\lib\site-packages (from keras>=2.2.4->keras-resnet) (1.19.2)
# Requirement already satisfied: h5py in c:\users\steven\anaconda3\envs\pruebas_ia\lib\site-packages (from keras>=2.2.4->keras-resnet) (2.10.0)
# Requirement already satisfied: scipy>=0.14 in c:\users\steven\anaconda3\envs\pruebas_ia\lib\site-packages (from keras>=2.2.4->keras-resnet) (1.6.2)
# Collecting pyyaml
#   Downloading PyYAML-5.4.1-cp37-cp37m-win_amd64.whl (210 kB)
# Requirement already satisfied: six in c:\users\steven\anaconda3\envs\pruebas_ia\lib\site-packages (from h5py->keras>=2.2.4->keras-resnet) (1.15.0)
# Building wheels for collected packages: keras-resnet
#   Building wheel for keras-resnet (setup.py): started
#   Building wheel for keras-resnet (setup.py): finished with status 'done'
#   Created wheel for keras-resnet: filename=keras_resnet-0.2.0-py2.py3-none-any.whl size=20486 sha256=4c93e78219b3d316188c535aa9511e74fbe02446973153228ccc80e842d6e1ca
#   Stored in directory: c:\users\steven\appdata\local\pip\cache\wheels\bd\ef\06\5d65f696360436c3a423020c4b7fd8c558c09ef264a0e6c575
# Successfully built keras-resnet
# Installing collected packages: pyyaml, keras, keras-resnet
# Successfully installed keras-2.4.3 keras-resnet-0.2.0 pyyaml-5.4.1
# Processing d:\universidad\computer_vision_uao\proyecto_de_curso_cvwdp\od_distanciamiento_social\keras-retinanet
# Requirement already satisfied: keras in c:\users\steven\anaconda3\envs\pruebas_ia\lib\site-packages (from keras-retinanet==0.4.1) (2.4.3)
# Requirement already satisfied: keras-resnet in c:\users\steven\anaconda3\envs\pruebas_ia\lib\site-packages (from keras-retinanet==0.4.1) (0.2.0)
# Requirement already satisfied: six in c:\users\steven\anaconda3\envs\pruebas_ia\lib\site-packages (from keras-retinanet==0.4.1) (1.15.0)
# Requirement already satisfied: scipy in c:\users\steven\anaconda3\envs\pruebas_ia\lib\site-packages (from keras-retinanet==0.4.1) (1.6.2)
# Requirement already satisfied: cython in c:\users\steven\anaconda3\envs\pruebas_ia\lib\site-packages (from keras-retinanet==0.4.1) (0.29.22)
# Requirement already satisfied: h5py in c:\users\steven\anaconda3\envs\pruebas_ia\lib\site-packages (from keras->keras-retinanet==0.4.1) (2.10.0)
# Requirement already satisfied: numpy>=1.9.1 in c:\users\steven\anaconda3\envs\pruebas_ia\lib\site-packages (from keras->keras-retinanet==0.4.1) (1.19.2)
# Requirement already satisfied: pyyaml in c:\users\steven\anaconda3\envs\pruebas_ia\lib\site-packages (from keras->keras-retinanet==0.4.1) (5.4.1)
# Building wheels for collected packages: keras-retinanet
#   Building wheel for keras-retinanet (setup.py): started
#   Building wheel for keras-retinanet (setup.py): finished with status 'done'
#   Created wheel for keras-retinanet: filename=keras_retinanet-0.4.1-cp37-cp37m-win_amd64.whl size=115713 sha256=634be2d430d4ba08cd92b21234551c8f13494ab2df6a527fb35c2a14612a6cdb
#   Stored in directory: c:\users\steven\appdata\local\pip\cache\wheels\08\d8\cf\5ab3ddd79bc2b27700f41b2eeae43da61e7b040b8359e69d7e
# Successfully built keras-retinanet
# Installing collected packages: keras-retinanet
# Successfully installed keras-retinanet-0.4.1

# %%
# !retinanet-train --batch-size 1 --steps 3809 --epochs 50 --weights D:/Universidad/Computer_Vision_UAO/Proyecto_de_curso_CVwDP/od_distanciamiento_social/keras-retinanet/resnet50_coco_best_v2.1.0.h5 --snapshot-path D:/Universidad/Computer_Vision_UAO/Proyecto_de_curso_CVwDP/od_distanciamiento_social/keras-retinanet/retinanet_snapshots csv D:/Universidad/Computer_Vision_UAO/Proyecto_de_curso_CVwDP/od_distanciamiento_social/keras-retinanet/entrenamiento1000.txt D:/Universidad/Computer_Vision_UAO/Proyecto_de_curso_CVwDP/od_distanciamiento_social/keras-retinanet/retinanet_classes.csv

# %% [markdown]
# **Exportar nuestro modelo a .h5**

# %%
# !retinanet-convert-model D:/Universidad/Computer_Vision_UAO/Proyecto_de_curso_CVwDP/od_distanciamiento_social/keras-retinanet/retinanet_snapshots/resnet50_csv_50.h5 retinanet_weights_person.h5

# %% [markdown]
# **Testear Modelo Entrenado**

# %%
# !retinanet-evaluate csv D:/Universidad/Computer_Vision_UAO/Proyecto_de_curso_CVwDP/od_distanciamiento_social/keras-retinanet/test1000.txt D:/Universidad/Computer_Vision_UAO/Proyecto_de_curso_CVwDP/od_distanciamiento_social/keras-retinanet/retinanet_classes.csv retinanet_weights_person.h5

# %% [markdown]
# **Usar Modelo para predicciones**

# %%
# import the necessary packages
from keras_retinanet.utils.image import preprocess_image
from keras_retinanet.utils.image import read_image_bgr
from keras_retinanet.utils.image import resize_image
from keras_retinanet import models
from matplotlib import pyplot as plt
import numpy as np

import cv2

labels= "D:/Universidad/Computer_Vision_UAO/Proyecto_de_curso_CVwDP/od_distanciamiento_social/keras-retinanet/retinanet_classes.csv"
base_path = "D:/Universidad/Computer_Vision_UAO/Proyecto_de_curso_CVwDP/od_distanciamiento_social/keras-retinanet"
model_dir="D:/Universidad/Computer_Vision_UAO/Proyecto_de_curso_CVwDP/od_distanciamiento_social/retinanet_weights_person_uao_v1.h5"
image_test= "D:/Universidad/Computer_Vision_UAO/Proyecto_de_curso_CVwDP/od_distanciamiento_social/keras-retinanet/3.jpeg"
min_confidence=0.7

# load the class label mappings
LABELS = open(labels).read().strip().split("\n")
LABELS = {int(L.split(",")[1]): L.split(",")[0] for L in LABELS}

# load the model from disk
model = models.load_model(model_dir, backbone_name="resnet50")

# load the input image (in BGR order), clone it, and preprocess it
image = read_image_bgr(image_test)
output = image.copy()
image = preprocess_image(image)
(image, scale) = resize_image(image)
image = np.expand_dims(image, axis=0)

# detect objects in the input image and correct for the image scale
(boxes, scores, labels) = model.predict_on_batch(image)
boxes /= scale

# loop over the detections
for (box, score, label) in zip(boxes[0], scores[0], labels[0]):
	# filter out weak detections
	if score < min_confidence:
		continue

	# convert the bounding box coordinates from floats to integers
	box = box.astype("int")

	# build the label and draw the label + bounding box on the output
	# image
	label = "{}: {:.2f}".format(LABELS[label], score)
	cv2.rectangle(output, (box[0], box[1]), (box[2], box[3]),
		(0, 255, 0), 2)
	cv2.putText(output, label, (box[0], box[1] - 10),
		cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

image_rgb=cv2.cvtColor(output,cv2.COLOR_BGR2RGB)
#image_rgb=cv2.resize(image_rgb)
# show the output image
plt.figure(figsize=(30,10))
plt.title('Resultado')
plt.axis("off")
plt.imshow(image_rgb)
plt.savefig(base_path+"salida_retinanet_personas.png")
plt.show()

# %%
import imutils
import argparse
import cv2
from keras_retinanet.utils.image import preprocess_image
from keras_retinanet.utils.image import read_image_bgr
from keras_retinanet.utils.image import resize_image
from keras_retinanet import models
from matplotlib import pyplot as plt
import numpy as np
import time


labels= "D:/Universidad/Computer_Vision_UAO/Proyecto_de_curso_CVwDP/od_distanciamiento_social/keras-retinanet/retinanet_classes.csv"
base_path = "D:/Universidad/Computer_Vision_UAO/Proyecto_de_curso_CVwDP/od_distanciamiento_social/keras-retinanet"
model_dir="D:/Universidad/Computer_Vision_UAO/Proyecto_de_curso_CVwDP/od_distanciamiento_social/retinanet_weights_person_uao_v1.h5"
min_confidence=0.7

vs = cv2.VideoCapture("D:\Proyectos_DL\Proyectos_RAMI\Proyectos_RAMI_IA\opencv-dnn-gpu-examples\example_videos\example_04.mp4")
writer = None



# keep looping
while True:
    # grab the current frame
    (grabbed, frame) = vs.read()
   

    # if we are viewing a video and we did not grab a
    # frame, then we have reached the end of the video
    if vs and not grabbed:
        break

    # resize the frame and convert it to grayscale
    frame = imutils.resize(frame, width = 800)
    image_test= cv2.cvtColor(frame, cv2.COLOR_RGB2BGR)
    



    # load the class label mappings
    LABELS = open(labels).read().strip().split("\n")
    LABELS = {int(L.split(",")[1]): L.split(",")[0] for L in LABELS}
    
    # load the model from disk
    model = models.load_model(model_dir, backbone_name="resnet50")
    
    # load the input image (in BGR order), clone it, and preprocess it
    image = image_test
    output = image.copy()
    image = preprocess_image(image)
    (image, scale) = resize_image(image)
    image = np.expand_dims(image, axis=0)
    
    # detect objects in the input image and correct for the image scale
    (boxes, scores, labels) = model.predict_on_batch(image)
    boxes /= scale
    
    # loop over the detections
    for (box, score, label) in zip(boxes[0], scores[0], labels[0]):
    	# filter out weak detections
    	if score < min_confidence:
    		continue
    
    	# convert the bounding box coordinates from floats to integers
    	box = box.astype("int")
    
    	# build the label and draw the label + bounding box on the output
    	# image
    	label = "{}: {:.2f}".format(LABELS[label], score)
    	cv2.rectangle(output, (box[0], box[1]), (box[2], box[3]),
    		(0, 255, 0), 2)
    	cv2.putText(output, label, (box[0], box[1] - 10),
    		cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
    
    image_rgb=cv2.cvtColor(output,cv2.COLOR_BGR2RGB)

    # show our detected faces
    cv2.imshow("People detection", image_rgb)
    time.sleep(2)

    key = cv2.waitKey(1) & 0xFF
 
    # if the `q` key was pressed, break from the loop
    if key == ord("q"):
        break


# cleanup the camera and close any open windows
cv2.destroyAllWindows()
vs.release()
# Out:
# Using TensorFlow backend.
# C:\Users\steven\anaconda3\envs\deepia\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\steven\anaconda3\envs\deepia\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\steven\anaconda3\envs\deepia\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\steven\anaconda3\envs\deepia\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\steven\anaconda3\envs\deepia\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\steven\anaconda3\envs\deepia\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\steven\anaconda3\envs\deepia\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\steven\anaconda3\envs\deepia\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\steven\anaconda3\envs\deepia\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\steven\anaconda3\envs\deepia\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\steven\anaconda3\envs\deepia\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\steven\anaconda3\envs\deepia\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# WARNING:tensorflow:From C:\Users\steven\anaconda3\envs\deepia\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\steven\anaconda3\envs\deepia\lib\site-packages\keras\backend\tensorflow_backend.py:4115: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# WARNING:tensorflow:From C:\Users\steven\anaconda3\envs\deepia\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From C:\Users\steven\anaconda3\envs\deepia\lib\site-packages\keras\backend\tensorflow_backend.py:1919: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From C:\Users\steven\anaconda3\envs\deepia\lib\site-packages\keras\backend\tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From C:\Users\steven\anaconda3\envs\deepia\lib\site-packages\keras\backend\tensorflow_backend.py:4185: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# WARNING:tensorflow:From C:\Users\steven\anaconda3\envs\deepia\lib\site-packages\keras_retinanet\backend\tensorflow_backend.py:62: The name tf.image.resize_images is deprecated. Please use tf.image.resize instead.
#
# WARNING:tensorflow:From C:\Users\steven\anaconda3\envs\deepia\lib\site-packages\keras_retinanet\backend\tensorflow_backend.py:98: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\Users\steven\anaconda3\envs\deepia\lib\site-packages\keras\backend\tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
# C:\Users\steven\anaconda3\envs\deepia\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
# C:\Users\steven\anaconda3\envs\deepia\lib\site-packages\ipykernel_launcher.py:40: DeprecationWarning: path should be string, bytes, or os.PathLike, not numpy.ndarray
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-1-e06365ce5f29> in <module>
#      38
#      39     # load the class label mappings
# ---> 40     LABELS = open(labels).read().strip().split("\n")
#      41     LABELS = {int(L.split(",")[1]): L.split(",")[0] for L in LABELS}
#      42
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xff in position 240: invalid start byte
