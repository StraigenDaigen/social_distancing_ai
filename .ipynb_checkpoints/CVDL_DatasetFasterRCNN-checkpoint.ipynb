# %%
# %cd D:/Steven/Proyecto_de_curso_CVwDP/dataset
# Out:
# D:\Steven\Proyecto_de_curso_CVwDP\dataset

# %%
import pandas as pd

# %%
#Asignando 3 variables a las tablas de datos separados por coma de openimage
img_box_nombre ='D:/Steven/od_distanciamiento_social/train-images-boxable-with-rotation.csv'
anota_box_nombre = 'D:/Steven/od_distanciamiento_social/train-annotations-bbox.csv'
clase_desc_nombre = 'D:/Steven/od_distanciamiento_social/class-descriptions-boxable.csv'

# %%
#Comprendiendo como son los encabezados de cada tabla pasada a dataframe
img_box_pd = pd.read_csv(img_box_nombre)
img_box_pd.head(5)
# Out:
#             ImageID Subset                                        OriginalURL  \
# 0  4fa8054781a4c382  train  https://farm3.staticflickr.com/5310/5898076654...
# 1  b37f763ae67d0888  train  https://c1.staticflickr.com/1/67/197493648_628...
# 2  7e8584b0f487cb9e  train  https://c7.staticflickr.com/8/7056/7143870979_...
# 3  86638230febe21c4  train  https://farm5.staticflickr.com/5128/5301868579...
# 4  249086e72671397d  train  https://c6.staticflickr.com/4/3930/15342460029...
#
#                                   OriginalLandingURL  \
# 0  https://www.flickr.com/photos/michael-beat/589...
# 1  https://www.flickr.com/photos/drstarbuck/19749...
# 2  https://www.flickr.com/photos/circasassy/71438...
# 3  https://www.flickr.com/photos/ajcreencia/53018...
# 4  https://www.flickr.com/photos/codnewsroom/1534...
#
#                                         License  \
# 0  https://creativecommons.org/licenses/by/2.0/
# 1  https://creativecommons.org/licenses/by/2.0/
# 2  https://creativecommons.org/licenses/by/2.0/
# 3  https://creativecommons.org/licenses/by/2.0/
# 4  https://creativecommons.org/licenses/by/2.0/
#
#                               AuthorProfileURL        Author  \
# 0  https://www.flickr.com/people/michael-beat/  Michael Beat
# 1    https://www.flickr.com/people/drstarbuck/         Karen
# 2    https://www.flickr.com/people/circasassy/    CircaSassy
# 3    https://www.flickr.com/people/ajcreencia/          Alex
# 4   https://www.flickr.com/people/codnewsroom/  COD Newsroom
#
#                                                Title  OriginalSize  \
# 0                                   ...die FNF-Kerze       4405052
# 1                               Three boys on a hill        494555
# 2  A Christmas carol and The cricket on the heart...       2371584
# 3                                    Abbey and Kenny        949267
# 4  Suburban Law Enforcement Academy 20th Annivers...       6541758
#
#                 OriginalMD5  \
# 0  KFukvivpCM5QXl5SqKe41g==
# 1  9IzEn38GRNsVpATuv7gzEA==
# 2  3hQwu0iSzY1VIoXiwp0/Mg==
# 3  onB+rCZnGQg5PRX7xOs18Q==
# 4  MjpaAVbMAWbCusSaxI1D7w==
#
#                                     Thumbnail300KURL  Rotation
# 0  https://c1.staticflickr.com/6/5310/5898076654_...       0.0
# 1  https://c3.staticflickr.com/1/67/197493648_628...       0.0
# 2  https://c7.staticflickr.com/8/7056/7143870979_...       0.0
# 3  https://c4.staticflickr.com/6/5128/5301868579_...       NaN
# 4  https://c1.staticflickr.com/4/3930/15342460029...       0.0

# %%
anota_box_pd = pd.read_csv(anota_box_nombre)
anota_box_pd.head(5)
# Out:
#             ImageID  Source  LabelName  Confidence      XMin      XMax  \
# 0  000002b66c9c498e  xclick  /m/01g317           1  0.012500  0.195312
# 1  000002b66c9c498e  xclick  /m/01g317           1  0.025000  0.276563
# 2  000002b66c9c498e  xclick  /m/01g317           1  0.151562  0.310937
# 3  000002b66c9c498e  xclick  /m/01g317           1  0.256250  0.429688
# 4  000002b66c9c498e  xclick  /m/01g317           1  0.257812  0.346875
#
#        YMin      YMax  IsOccluded  IsTruncated  IsGroupOf  IsDepiction  \
# 0  0.148438  0.587500           0            1          0            0
# 1  0.714063  0.948438           0            1          0            0
# 2  0.198437  0.590625           1            0          0            0
# 3  0.651563  0.925000           1            0          0            0
# 4  0.235938  0.385938           1            0          0            0
#
#    IsInside
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %%
#Para este caso toca  asegurarse de no tomar en cuenta encabezado por que no tiene
clas_desc_pd = pd.read_csv(clase_desc_nombre, header=None)
clas_desc_pd.head()
# Out:
#              0           1
# 0    /m/011k07    Tortoise
# 1  /m/011q46kg   Container
# 2    /m/012074      Magpie
# 3    /m/0120dh  Sea turtle
# 4    /m/01226z    Football

# %%
import random
import os
from skimage import io
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %%
#Este código es irrelevante, solo sirve para tomar aleatoriamente imagenes a partir de su ID
test_img_id = anota_box_pd["ImageID"].value_counts().head(100).index.values
test_img_id = random.sample(list(test_img_id),1)
print(test_img_id)
#test_img_id =['ca6e2a230f1576b6']  #persona   ['113a08c061582251'] #cafe  ['3c095a6526719d58'] #araña ['72d8ea9eb960c980'] #muchas cosas
#test_img_id=['371dfb0603858dbb']#['d311f6ba6548e60e']
# Out:
# ['8515047318174835']

# %%
#Este codigo muestra todas las boxes dentro de una imagen. Luego será usado nuevamente
img_url =img_box_pd.loc[img_box_pd["ImageID"]==test_img_id[0]]['OriginalURL'].values[0]
img = io.imread(img_url)
h,w,ch =img.shape
bbox = anota_box_pd[anota_box_pd['ImageID']==test_img_id[0]]
for i,f in bbox.iterrows():
  xmin =int(f['XMin']*w)
  xmax = int(f['XMax']*w)
  ymin = int(f['YMin']*h)
  ymax = int(f['YMax']*h)
  label = f['LabelName']
  clase = clas_desc_pd[clas_desc_pd[0]==label]
  cv2.rectangle(img, (xmin,ymin), (xmax,ymax), (255,0,0), 5)
  font = cv2.FONT_HERSHEY_SIMPLEX
  cv2.putText(img, clase[1].values[0], (xmin,ymin-10), font, 3, (0,255,0), 5)
plt.figure(figsize=(15,10))
plt.title('Image with Bounding Box')
plt.imshow(img)
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-30-49681c2200d0> in <module>
#       1 #Este codigo muestra todas las boxes dentro de una imagen. Luego será usado nuevamente
#       2 img_url =img_box_pd.loc[img_box_pd["ImageID"]==test_img_id[0]]['OriginalURL'].values[0]
# ----> 3 img = io.imread(img_url)
#       4 h,w,ch =img.shape
#       5 bbox = anota_box_pd[anota_box_pd['ImageID']==test_img_id[0]]
#
# ~\Anaconda3\envs\deepia\lib\site-packages\skimage\io\_io.py in imread(fname, as_gray, plugin, **plugin_args)
#      45             plugin = 'tifffile'
#      46
# ---> 47     with file_or_url_context(fname) as fname:
#      48         img = call_plugin('imread', fname, plugin=plugin, **plugin_args)
#      49
#
# ~\Anaconda3\envs\deepia\lib\contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# ~\Anaconda3\envs\deepia\lib\site-packages\skimage\io\util.py in file_or_url_context(resource_name)
#      26         try:
#      27             with tempfile.NamedTemporaryFile(delete=False, suffix=ext) as f:
# ---> 28                 u = urllib.request.urlopen(resource_name)
#      29                 f.write(u.read())
#      30             # f must be closed before yielding
#
# ~\Anaconda3\envs\deepia\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\Anaconda3\envs\deepia\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~\Anaconda3\envs\deepia\lib\urllib\request.py in http_response(self, request, response)
#     639         if not (200 <= code < 300):
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#     643         return response
#
# ~\Anaconda3\envs\deepia\lib\urllib\request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# ~\Anaconda3\envs\deepia\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# ~\Anaconda3\envs\deepia\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 404: Not Found

# %%
#Buscar en la tabla de descripciones de clases los ID de Personas y Carros
clas_desc_pd.loc[clas_desc_pd[1].isin(['Person'])]

# %%
#Tomemos aleatoriamente 100 imagenes de personas y 100 de carros
#Lineas de clases
persona_pd =clas_desc_pd[clas_desc_pd[1]=='Person']
#Etiquetas de clases (Estas etiquetas serán primordiales cuando se vaya a copiar a disco local)
persona_label_pd = persona_pd[0].values[0]
#Usemos las etiquetas para bajar las box de anotaciones
persona_box_an= anota_box_pd[anota_box_pd['LabelName']==persona_label_pd]
#Bajemos los ID de las clases
persona_id=persona_box_an['ImageID']
#Dado que pueden haber varias personas en una imagen, podrían aparecer ID's repetidos. Vamos a usar una sola
persona_id = np.unique(persona_id)
#******Escoger aleatoriamente 1000 imagenes de cada clase
n=1000
sub_persona_id =random.sample(list(persona_id),n)

# %%
#Usemos pandas para crear los dos conjuntos de datos a partir de los Sub ID's
sub_persona_pd = img_box_pd.loc[img_box_pd['ImageID'].isin(sub_persona_id)]
sub_persona_pd.shape

# %%
sub_persona_pd.head()

# %%
#Convirtiendo los dos subgrupos de imagenes en diccionarios.
sub_persona_dict =sub_persona_pd[['ImageID', 'OriginalURL']].set_index('ImageID')["OriginalURL"].to_dict()

# %%
clases = [sub_persona_dict]

# %%
len(clases[0])

# %%
#Creando dos carpetas en el ambiente virtual para copiar las imagenes de los dos subgrupos
# !mkdir "Person"

# %%
"""Salvando las imagenes a nuestros directorios locales. Observe el uso de "try" porque 
es posible que alguna dirección ya no exista"""
c=0
for i,o in enumerate(['Person']):
  errores=0
  
  for img_id, url in clases[i].items():
    try:
      c += 1
      print("guardando img {}".format(c))
      img = io.imread(url)
      ruta = o +'/'+img_id+".jpg"
      io.imsave(ruta,img)
    except Exception as e:
      errores+=1
  print(f"Imagenes perdidas:{errores}")

# %%
#Creemos los directorios de train y test en nuestro drive
# !mkdir "D:/Steven/Proyecto_de_curso_CVwDP/dataset/train1000"
# !mkdir "D:/Steven/Proyecto_de_curso_CVwDP/dataset/test1000"

train_path="D:/Steven/Proyecto_de_curso_CVwDP/dataset/train1000/"
test_path="D:/Steven/Proyecto_de_curso_CVwDP/dataset/test1000/"
# Out:
# Ya existe el subdirectorio o el archivo D:/Universidad/Computer_Vision_UAO/Proyecto_de_curso_CVwDP/dataset/train1000.
# Ya existe el subdirectorio o el archivo D:/Universidad/Computer_Vision_UAO/Proyecto_de_curso_CVwDP/dataset/test1000.

# %%
from shutil import copyfile

# %%
"""Este codigo nos permite tomar el 80% de las 200 imagenes (carros y personas) y
copiarlas a la carpeta train. El 20% restante copiadas a la carpeta test."""
clas=['Person']
for i in range(len(clas)):
  imgs = os.listdir(clas[i])
  random.shuffle(imgs)
  percent = int(n*0.8)
  train_imgs=imgs[:percent]
  test_imgs = imgs[percent:]

  for f in range(len(train_imgs)):
    src = os.path.join(clas[i],train_imgs[f])
    dst = os.path.join(train_path+train_imgs[f])
    copyfile(src,dst)
  for f in range(len(test_imgs)):
    src = os.path.join(clas[i],test_imgs[f])
    dst = os.path.join(test_path+test_imgs[f])
    copyfile(src,dst)
#print(imgs)

# %%
import sys

# %%
"""Aqui creamos un dataframe de pandas con la información
que es necesaria para nuestro entrenamiento: nombre del archivo imagen,
x1,x2,y1,y2 (datos de la box) y la etiqueta de clase (Persona o Carro).""" 
clas=['Person']
etiquetas =[persona_label_pd]
train_df = pd.DataFrame(columns=['Nombre','Xmin','Xmax','Ymin', 'Ymax','Label'])

train_imgs = os.listdir(train_path)
c=0
for i in range(len(train_imgs)):
  c=c+1
  print("imagen procesada para train: {}".format(c))
  sys.stdout.flush()
  img_nombre = train_imgs[i]
  img_id=img_nombre[0:16]
  tmp_df = anota_box_pd[anota_box_pd['ImageID']==img_id]
  for index, row in tmp_df.iterrows():
    labelName = row['LabelName']
    for i in range(len(etiquetas)):
      if labelName == etiquetas[i]:
        train_df = train_df.append({'Nombre':img_nombre,
                                    'Xmin':row['XMin'],
                                    'Xmax':row['XMax'],
                                    'Ymin':row['YMin'],
                                    'Ymax':row['YMax'],
                                    'Label':clas[i]},
                                   ignore_index=True)
# Out:
# imagen procesada para train: 1
# imagen procesada para train: 2
# imagen procesada para train: 3
# imagen procesada para train: 4
# imagen procesada para train: 5
# imagen procesada para train: 6
# imagen procesada para train: 7
# imagen procesada para train: 8
# imagen procesada para train: 9
# imagen procesada para train: 10
# imagen procesada para train: 11
# imagen procesada para train: 12
# imagen procesada para train: 13
# imagen procesada para train: 14
# imagen procesada para train: 15
# imagen procesada para train: 16
# imagen procesada para train: 17
# imagen procesada para train: 18
# imagen procesada para train: 19
# imagen procesada para train: 20
# imagen procesada para train: 21
# imagen procesada para train: 22
# imagen procesada para train: 23
# imagen procesada para train: 24
# imagen procesada para train: 25
# imagen procesada para train: 26
# imagen procesada para train: 27
# imagen procesada para train: 28
# imagen procesada para train: 29
# imagen procesada para train: 30
# imagen procesada para train: 31
# imagen procesada para train: 32
# imagen procesada para train: 33
# imagen procesada para train: 34
# imagen procesada para train: 35
# imagen procesada para train: 36
# imagen procesada para train: 37
# imagen procesada para train: 38
# imagen procesada para train: 39
# imagen procesada para train: 40
# imagen procesada para train: 41
# imagen procesada para train: 42
# imagen procesada para train: 43
# imagen procesada para train: 44
# imagen procesada para train: 45
# imagen procesada para train: 46
# imagen procesada para train: 47
# imagen procesada para train: 48
# imagen procesada para train: 49
# imagen procesada para train: 50
# imagen procesada para train: 51
# imagen procesada para train: 52
# imagen procesada para train: 53
# imagen procesada para train: 54
# imagen procesada para train: 55
# imagen procesada para train: 56
# imagen procesada para train: 57
# imagen procesada para train: 58
# imagen procesada para train: 59
# imagen procesada para train: 60
# imagen procesada para train: 61
# imagen procesada para train: 62
# imagen procesada para train: 63
# imagen procesada para train: 64
# imagen procesada para train: 65
# imagen procesada para train: 66
# imagen procesada para train: 67
# imagen procesada para train: 68
# imagen procesada para train: 69
# imagen procesada para train: 70
# imagen procesada para train: 71
# imagen procesada para train: 72
# imagen procesada para train: 73
# imagen procesada para train: 74
# imagen procesada para train: 75
# imagen procesada para train: 76
# imagen procesada para train: 77
# imagen procesada para train: 78
# imagen procesada para train: 79
# imagen procesada para train: 80
# imagen procesada para train: 81
# imagen procesada para train: 82
# imagen procesada para train: 83
# imagen procesada para train: 84
# imagen procesada para train: 85
# imagen procesada para train: 86
# imagen procesada para train: 87
# imagen procesada para train: 88
# imagen procesada para train: 89
# imagen procesada para train: 90
# imagen procesada para train: 91
# imagen procesada para train: 92
# imagen procesada para train: 93
# imagen procesada para train: 94
# imagen procesada para train: 95
# imagen procesada para train: 96
# imagen procesada para train: 97
# imagen procesada para train: 98
# imagen procesada para train: 99
# imagen procesada para train: 100
# imagen procesada para train: 101
# imagen procesada para train: 102
# imagen procesada para train: 103
# imagen procesada para train: 104
# imagen procesada para train: 105
# imagen procesada para train: 106
# imagen procesada para train: 107
# imagen procesada para train: 108
# imagen procesada para train: 109
# imagen procesada para train: 110
# imagen procesada para train: 111
# imagen procesada para train: 112
# imagen procesada para train: 113
# imagen procesada para train: 114
# imagen procesada para train: 115
# imagen procesada para train: 116
# imagen procesada para train: 117
# imagen procesada para train: 118
# imagen procesada para train: 119
# imagen procesada para train: 120
# imagen procesada para train: 121
# imagen procesada para train: 122
# imagen procesada para train: 123
# imagen procesada para train: 124
# imagen procesada para train: 125
# imagen procesada para train: 126
# imagen procesada para train: 127
# imagen procesada para train: 128
# imagen procesada para train: 129
# imagen procesada para train: 130
# imagen procesada para train: 131
# imagen procesada para train: 132
# imagen procesada para train: 133
# imagen procesada para train: 134
# imagen procesada para train: 135
# imagen procesada para train: 136
# imagen procesada para train: 137
# imagen procesada para train: 138
# imagen procesada para train: 139
# imagen procesada para train: 140
# imagen procesada para train: 141
# imagen procesada para train: 142
# imagen procesada para train: 143
# imagen procesada para train: 144
# imagen procesada para train: 145
# imagen procesada para train: 146
# imagen procesada para train: 147
# imagen procesada para train: 148
# imagen procesada para train: 149
# imagen procesada para train: 150
# imagen procesada para train: 151
# imagen procesada para train: 152
# imagen procesada para train: 153
# imagen procesada para train: 154
# imagen procesada para train: 155
# imagen procesada para train: 156
# imagen procesada para train: 157
# imagen procesada para train: 158
# imagen procesada para train: 159
# imagen procesada para train: 160
# imagen procesada para train: 161
# imagen procesada para train: 162
# imagen procesada para train: 163
# imagen procesada para train: 164
# imagen procesada para train: 165
# imagen procesada para train: 166
# imagen procesada para train: 167
# imagen procesada para train: 168
# imagen procesada para train: 169
# imagen procesada para train: 170
# imagen procesada para train: 171
# imagen procesada para train: 172
# imagen procesada para train: 173
# imagen procesada para train: 174
# imagen procesada para train: 175
# imagen procesada para train: 176
# imagen procesada para train: 177
# imagen procesada para train: 178
# imagen procesada para train: 179
# imagen procesada para train: 180
# imagen procesada para train: 181
# imagen procesada para train: 182
# imagen procesada para train: 183
# imagen procesada para train: 184
# imagen procesada para train: 185
# imagen procesada para train: 186
# imagen procesada para train: 187
# imagen procesada para train: 188
# imagen procesada para train: 189
# imagen procesada para train: 190
# imagen procesada para train: 191
# imagen procesada para train: 192
# imagen procesada para train: 193
# imagen procesada para train: 194
# imagen procesada para train: 195
# imagen procesada para train: 196
# imagen procesada para train: 197
# imagen procesada para train: 198
# imagen procesada para train: 199
# imagen procesada para train: 200
# imagen procesada para train: 201
# imagen procesada para train: 202
# imagen procesada para train: 203
# imagen procesada para train: 204
# imagen procesada para train: 205
# imagen procesada para train: 206
# imagen procesada para train: 207
# imagen procesada para train: 208
# imagen procesada para train: 209
# imagen procesada para train: 210
# imagen procesada para train: 211
# imagen procesada para train: 212
# imagen procesada para train: 213
# imagen procesada para train: 214
# imagen procesada para train: 215
# imagen procesada para train: 216
# imagen procesada para train: 217
# imagen procesada para train: 218
# imagen procesada para train: 219
# imagen procesada para train: 220
# imagen procesada para train: 221
# imagen procesada para train: 222
# imagen procesada para train: 223
# imagen procesada para train: 224
# imagen procesada para train: 225
# imagen procesada para train: 226
# imagen procesada para train: 227
# imagen procesada para train: 228
# imagen procesada para train: 229
# imagen procesada para train: 230
# imagen procesada para train: 231
# imagen procesada para train: 232
# imagen procesada para train: 233
# imagen procesada para train: 234
# imagen procesada para train: 235
# imagen procesada para train: 236
# imagen procesada para train: 237
# imagen procesada para train: 238
# imagen procesada para train: 239
# imagen procesada para train: 240
# imagen procesada para train: 241
# imagen procesada para train: 242
# imagen procesada para train: 243
# imagen procesada para train: 244
# imagen procesada para train: 245
# imagen procesada para train: 246
# imagen procesada para train: 247
# imagen procesada para train: 248
# imagen procesada para train: 249
# imagen procesada para train: 250
# imagen procesada para train: 251
# imagen procesada para train: 252
# imagen procesada para train: 253
# imagen procesada para train: 254
# imagen procesada para train: 255
# imagen procesada para train: 256
# imagen procesada para train: 257
# imagen procesada para train: 258
# imagen procesada para train: 259
# imagen procesada para train: 260
# imagen procesada para train: 261
# imagen procesada para train: 262
# imagen procesada para train: 263
# imagen procesada para train: 264
# imagen procesada para train: 265
# imagen procesada para train: 266
# imagen procesada para train: 267
# imagen procesada para train: 268
# imagen procesada para train: 269
# imagen procesada para train: 270
# imagen procesada para train: 271
# imagen procesada para train: 272
# imagen procesada para train: 273
# imagen procesada para train: 274
# imagen procesada para train: 275
# imagen procesada para train: 276
# imagen procesada para train: 277
# imagen procesada para train: 278
# imagen procesada para train: 279
# imagen procesada para train: 280
# imagen procesada para train: 281
# imagen procesada para train: 282
# imagen procesada para train: 283
# imagen procesada para train: 284
# imagen procesada para train: 285
# imagen procesada para train: 286
# imagen procesada para train: 287
# imagen procesada para train: 288
# imagen procesada para train: 289
# imagen procesada para train: 290
# imagen procesada para train: 291
# imagen procesada para train: 292
# imagen procesada para train: 293
# imagen procesada para train: 294
# imagen procesada para train: 295
# imagen procesada para train: 296
# imagen procesada para train: 297
# imagen procesada para train: 298
# imagen procesada para train: 299
# imagen procesada para train: 300
# imagen procesada para train: 301
# imagen procesada para train: 302
# imagen procesada para train: 303
# imagen procesada para train: 304
# imagen procesada para train: 305
# imagen procesada para train: 306
# imagen procesada para train: 307
# imagen procesada para train: 308
# imagen procesada para train: 309
# imagen procesada para train: 310
# imagen procesada para train: 311
# imagen procesada para train: 312
# imagen procesada para train: 313
# imagen procesada para train: 314
# imagen procesada para train: 315
# imagen procesada para train: 316
# imagen procesada para train: 317
# imagen procesada para train: 318
# imagen procesada para train: 319
# imagen procesada para train: 320
# imagen procesada para train: 321
# imagen procesada para train: 322
# imagen procesada para train: 323
# imagen procesada para train: 324
# imagen procesada para train: 325
# imagen procesada para train: 326
# imagen procesada para train: 327
# imagen procesada para train: 328
# imagen procesada para train: 329
# imagen procesada para train: 330
# imagen procesada para train: 331
# imagen procesada para train: 332
# imagen procesada para train: 333
# imagen procesada para train: 334
# imagen procesada para train: 335
# imagen procesada para train: 336
# imagen procesada para train: 337
# imagen procesada para train: 338
# imagen procesada para train: 339
# imagen procesada para train: 340
# imagen procesada para train: 341
# imagen procesada para train: 342
# imagen procesada para train: 343
# imagen procesada para train: 344
# imagen procesada para train: 345
# imagen procesada para train: 346
# imagen procesada para train: 347
# imagen procesada para train: 348
# imagen procesada para train: 349
# imagen procesada para train: 350
# imagen procesada para train: 351
# imagen procesada para train: 352
# imagen procesada para train: 353
# imagen procesada para train: 354
# imagen procesada para train: 355
# imagen procesada para train: 356
# imagen procesada para train: 357
# imagen procesada para train: 358
# imagen procesada para train: 359
# imagen procesada para train: 360
# imagen procesada para train: 361
# imagen procesada para train: 362
# imagen procesada para train: 363
# imagen procesada para train: 364
# imagen procesada para train: 365
# imagen procesada para train: 366
# imagen procesada para train: 367
# imagen procesada para train: 368
# imagen procesada para train: 369
# imagen procesada para train: 370
# imagen procesada para train: 371
# imagen procesada para train: 372
# imagen procesada para train: 373
# imagen procesada para train: 374
# imagen procesada para train: 375
# imagen procesada para train: 376
# imagen procesada para train: 377
# imagen procesada para train: 378
# imagen procesada para train: 379
# imagen procesada para train: 380
# imagen procesada para train: 381
# imagen procesada para train: 382
# imagen procesada para train: 383
# imagen procesada para train: 384
# imagen procesada para train: 385
# imagen procesada para train: 386
# imagen procesada para train: 387
# imagen procesada para train: 388
# imagen procesada para train: 389
# imagen procesada para train: 390
# imagen procesada para train: 391
# imagen procesada para train: 392
# imagen procesada para train: 393
# imagen procesada para train: 394
# imagen procesada para train: 395
# imagen procesada para train: 396
# imagen procesada para train: 397
# imagen procesada para train: 398
# imagen procesada para train: 399
# imagen procesada para train: 400
# imagen procesada para train: 401
# imagen procesada para train: 402
# imagen procesada para train: 403
# imagen procesada para train: 404
# imagen procesada para train: 405
# imagen procesada para train: 406
# imagen procesada para train: 407
# imagen procesada para train: 408
# imagen procesada para train: 409
# imagen procesada para train: 410
# imagen procesada para train: 411
# imagen procesada para train: 412
# imagen procesada para train: 413
# imagen procesada para train: 414
# imagen procesada para train: 415
# imagen procesada para train: 416
# imagen procesada para train: 417
# imagen procesada para train: 418
# imagen procesada para train: 419
# imagen procesada para train: 420
# imagen procesada para train: 421
# imagen procesada para train: 422
# imagen procesada para train: 423
# imagen procesada para train: 424
# imagen procesada para train: 425
# imagen procesada para train: 426
# imagen procesada para train: 427
# imagen procesada para train: 428
# imagen procesada para train: 429
# imagen procesada para train: 430
# imagen procesada para train: 431
# imagen procesada para train: 432
# imagen procesada para train: 433
# imagen procesada para train: 434
# imagen procesada para train: 435
# imagen procesada para train: 436
# imagen procesada para train: 437
# imagen procesada para train: 438
# imagen procesada para train: 439
# imagen procesada para train: 440
# imagen procesada para train: 441
# imagen procesada para train: 442
# imagen procesada para train: 443
# imagen procesada para train: 444
# imagen procesada para train: 445
# imagen procesada para train: 446
# imagen procesada para train: 447
# imagen procesada para train: 448
# imagen procesada para train: 449
# imagen procesada para train: 450
# imagen procesada para train: 451
# imagen procesada para train: 452
# imagen procesada para train: 453
# imagen procesada para train: 454
# imagen procesada para train: 455
# imagen procesada para train: 456
# imagen procesada para train: 457
# imagen procesada para train: 458
# imagen procesada para train: 459
# imagen procesada para train: 460
# imagen procesada para train: 461
# imagen procesada para train: 462
# imagen procesada para train: 463
# imagen procesada para train: 464
# imagen procesada para train: 465
# imagen procesada para train: 466
# imagen procesada para train: 467
# imagen procesada para train: 468
# imagen procesada para train: 469
# imagen procesada para train: 470
# imagen procesada para train: 471
# imagen procesada para train: 472
# imagen procesada para train: 473
# imagen procesada para train: 474
# imagen procesada para train: 475
# imagen procesada para train: 476
# imagen procesada para train: 477
# imagen procesada para train: 478
# imagen procesada para train: 479
# imagen procesada para train: 480
# imagen procesada para train: 481
# imagen procesada para train: 482
# imagen procesada para train: 483
# imagen procesada para train: 484
# imagen procesada para train: 485
# imagen procesada para train: 486
# imagen procesada para train: 487
# imagen procesada para train: 488
# imagen procesada para train: 489
# imagen procesada para train: 490
# imagen procesada para train: 491
# imagen procesada para train: 492
# imagen procesada para train: 493
# imagen procesada para train: 494
# imagen procesada para train: 495
# imagen procesada para train: 496
# imagen procesada para train: 497
# imagen procesada para train: 498
# imagen procesada para train: 499
# imagen procesada para train: 500
# imagen procesada para train: 501
# imagen procesada para train: 502
# imagen procesada para train: 503
# imagen procesada para train: 504
# imagen procesada para train: 505
# imagen procesada para train: 506
# imagen procesada para train: 507
# imagen procesada para train: 508
# imagen procesada para train: 509
# imagen procesada para train: 510
# imagen procesada para train: 511
# imagen procesada para train: 512
# imagen procesada para train: 513
# imagen procesada para train: 514
# imagen procesada para train: 515
# imagen procesada para train: 516
# imagen procesada para train: 517
# imagen procesada para train: 518
# imagen procesada para train: 519
# imagen procesada para train: 520
# imagen procesada para train: 521
# imagen procesada para train: 522
# imagen procesada para train: 523
# imagen procesada para train: 524
# imagen procesada para train: 525
# imagen procesada para train: 526
# imagen procesada para train: 527
# imagen procesada para train: 528
# imagen procesada para train: 529
# imagen procesada para train: 530
# imagen procesada para train: 531
# imagen procesada para train: 532
# imagen procesada para train: 533
# imagen procesada para train: 534
# imagen procesada para train: 535
# imagen procesada para train: 536
# imagen procesada para train: 537
# imagen procesada para train: 538
# imagen procesada para train: 539
# imagen procesada para train: 540
# imagen procesada para train: 541
# imagen procesada para train: 542
# imagen procesada para train: 543
# imagen procesada para train: 544
# imagen procesada para train: 545
# imagen procesada para train: 546
# imagen procesada para train: 547
# imagen procesada para train: 548
# imagen procesada para train: 549
# imagen procesada para train: 550
# imagen procesada para train: 551
# imagen procesada para train: 552
# imagen procesada para train: 553
# imagen procesada para train: 554
# imagen procesada para train: 555
# imagen procesada para train: 556
# imagen procesada para train: 557
# imagen procesada para train: 558
# imagen procesada para train: 559
# imagen procesada para train: 560
# imagen procesada para train: 561
# imagen procesada para train: 562
# imagen procesada para train: 563
# imagen procesada para train: 564
# imagen procesada para train: 565
# imagen procesada para train: 566
# imagen procesada para train: 567
# imagen procesada para train: 568
# imagen procesada para train: 569
# imagen procesada para train: 570
# imagen procesada para train: 571
# imagen procesada para train: 572
# imagen procesada para train: 573
# imagen procesada para train: 574
# imagen procesada para train: 575
# imagen procesada para train: 576
# imagen procesada para train: 577
# imagen procesada para train: 578
# imagen procesada para train: 579
# imagen procesada para train: 580
# imagen procesada para train: 581
# imagen procesada para train: 582
# imagen procesada para train: 583
# imagen procesada para train: 584
# imagen procesada para train: 585
# imagen procesada para train: 586
# imagen procesada para train: 587
# imagen procesada para train: 588
# imagen procesada para train: 589
# imagen procesada para train: 590
# imagen procesada para train: 591
# imagen procesada para train: 592
# imagen procesada para train: 593
# imagen procesada para train: 594
# imagen procesada para train: 595
# imagen procesada para train: 596
# imagen procesada para train: 597
# imagen procesada para train: 598
# imagen procesada para train: 599
# imagen procesada para train: 600
# imagen procesada para train: 601
# imagen procesada para train: 602
# imagen procesada para train: 603
# imagen procesada para train: 604
# imagen procesada para train: 605
# imagen procesada para train: 606
# imagen procesada para train: 607
# imagen procesada para train: 608
# imagen procesada para train: 609
# imagen procesada para train: 610
# imagen procesada para train: 611
# imagen procesada para train: 612
# imagen procesada para train: 613
# imagen procesada para train: 614
# imagen procesada para train: 615
# imagen procesada para train: 616
# imagen procesada para train: 617
# imagen procesada para train: 618
# imagen procesada para train: 619
# imagen procesada para train: 620
# imagen procesada para train: 621
# imagen procesada para train: 622
# imagen procesada para train: 623
# imagen procesada para train: 624
# imagen procesada para train: 625
# imagen procesada para train: 626
# imagen procesada para train: 627
# imagen procesada para train: 628
# imagen procesada para train: 629
# imagen procesada para train: 630
# imagen procesada para train: 631
# imagen procesada para train: 632
# imagen procesada para train: 633
# imagen procesada para train: 634
# imagen procesada para train: 635
# imagen procesada para train: 636
# imagen procesada para train: 637
# imagen procesada para train: 638
# imagen procesada para train: 639
# imagen procesada para train: 640
# imagen procesada para train: 641
# imagen procesada para train: 642
# imagen procesada para train: 643
# imagen procesada para train: 644
# imagen procesada para train: 645
# imagen procesada para train: 646
# imagen procesada para train: 647
# imagen procesada para train: 648
# imagen procesada para train: 649
# imagen procesada para train: 650
# imagen procesada para train: 651
# imagen procesada para train: 652
# imagen procesada para train: 653
# imagen procesada para train: 654
# imagen procesada para train: 655
# imagen procesada para train: 656
# imagen procesada para train: 657
# imagen procesada para train: 658
# imagen procesada para train: 659
# imagen procesada para train: 660
# imagen procesada para train: 661
# imagen procesada para train: 662
# imagen procesada para train: 663
# imagen procesada para train: 664
# imagen procesada para train: 665
# imagen procesada para train: 666
# imagen procesada para train: 667
# imagen procesada para train: 668
# imagen procesada para train: 669
# imagen procesada para train: 670
# imagen procesada para train: 671
# imagen procesada para train: 672
# imagen procesada para train: 673
# imagen procesada para train: 674
# imagen procesada para train: 675
# imagen procesada para train: 676
# imagen procesada para train: 677
# imagen procesada para train: 678
# imagen procesada para train: 679
# imagen procesada para train: 680
# imagen procesada para train: 681
# imagen procesada para train: 682
# imagen procesada para train: 683
# imagen procesada para train: 684
# imagen procesada para train: 685
# imagen procesada para train: 686
# imagen procesada para train: 687
# imagen procesada para train: 688
# imagen procesada para train: 689
# imagen procesada para train: 690
# imagen procesada para train: 691
# imagen procesada para train: 692
# imagen procesada para train: 693
# imagen procesada para train: 694
# imagen procesada para train: 695
# imagen procesada para train: 696
# imagen procesada para train: 697
# imagen procesada para train: 698
# imagen procesada para train: 699
# imagen procesada para train: 700
# imagen procesada para train: 701
# imagen procesada para train: 702
# imagen procesada para train: 703
# imagen procesada para train: 704
# imagen procesada para train: 705
# imagen procesada para train: 706
# imagen procesada para train: 707
# imagen procesada para train: 708
# imagen procesada para train: 709
# imagen procesada para train: 710
# imagen procesada para train: 711
# imagen procesada para train: 712
# imagen procesada para train: 713
# imagen procesada para train: 714
# imagen procesada para train: 715
# imagen procesada para train: 716
# imagen procesada para train: 717
# imagen procesada para train: 718
# imagen procesada para train: 719
# imagen procesada para train: 720
# imagen procesada para train: 721
# imagen procesada para train: 722
# imagen procesada para train: 723
# imagen procesada para train: 724
# imagen procesada para train: 725
# imagen procesada para train: 726
# imagen procesada para train: 727
# imagen procesada para train: 728
# imagen procesada para train: 729
# imagen procesada para train: 730
# imagen procesada para train: 731
# imagen procesada para train: 732
# imagen procesada para train: 733
# imagen procesada para train: 734
# imagen procesada para train: 735
# imagen procesada para train: 736
# imagen procesada para train: 737
# imagen procesada para train: 738
# imagen procesada para train: 739
# imagen procesada para train: 740
# imagen procesada para train: 741
# imagen procesada para train: 742
# imagen procesada para train: 743
# imagen procesada para train: 744
# imagen procesada para train: 745
# imagen procesada para train: 746
# imagen procesada para train: 747
# imagen procesada para train: 748
# imagen procesada para train: 749
# imagen procesada para train: 750
# imagen procesada para train: 751
# imagen procesada para train: 752
# imagen procesada para train: 753
# imagen procesada para train: 754
# imagen procesada para train: 755
# imagen procesada para train: 756
# imagen procesada para train: 757
# imagen procesada para train: 758
# imagen procesada para train: 759
# imagen procesada para train: 760
# imagen procesada para train: 761
# imagen procesada para train: 762
# imagen procesada para train: 763
# imagen procesada para train: 764
# imagen procesada para train: 765
# imagen procesada para train: 766
# imagen procesada para train: 767
# imagen procesada para train: 768
# imagen procesada para train: 769
# imagen procesada para train: 770
# imagen procesada para train: 771
# imagen procesada para train: 772
# imagen procesada para train: 773
# imagen procesada para train: 774
# imagen procesada para train: 775
# imagen procesada para train: 776
# imagen procesada para train: 777
# imagen procesada para train: 778
# imagen procesada para train: 779
# imagen procesada para train: 780
# imagen procesada para train: 781
# imagen procesada para train: 782
# imagen procesada para train: 783
# imagen procesada para train: 784
# imagen procesada para train: 785
# imagen procesada para train: 786
# imagen procesada para train: 787
# imagen procesada para train: 788
# imagen procesada para train: 789
# imagen procesada para train: 790
# imagen procesada para train: 791
# imagen procesada para train: 792
# imagen procesada para train: 793
# imagen procesada para train: 794
# imagen procesada para train: 795
# imagen procesada para train: 796
# imagen procesada para train: 797
# imagen procesada para train: 798
# imagen procesada para train: 799
# imagen procesada para train: 800
# imagen procesada para train: 801
# imagen procesada para train: 802
# imagen procesada para train: 803
# imagen procesada para train: 804
# imagen procesada para train: 805
# imagen procesada para train: 806
# imagen procesada para train: 807
# imagen procesada para train: 808
# imagen procesada para train: 809
# imagen procesada para train: 810
# imagen procesada para train: 811
# imagen procesada para train: 812
# imagen procesada para train: 813
# imagen procesada para train: 814
# imagen procesada para train: 815
# imagen procesada para train: 816
# imagen procesada para train: 817
# imagen procesada para train: 818
# imagen procesada para train: 819
# imagen procesada para train: 820
# imagen procesada para train: 821
# imagen procesada para train: 822
# imagen procesada para train: 823
# imagen procesada para train: 824
# imagen procesada para train: 825
# imagen procesada para train: 826
# imagen procesada para train: 827
# imagen procesada para train: 828
# imagen procesada para train: 829
# imagen procesada para train: 830
# imagen procesada para train: 831
# imagen procesada para train: 832
# imagen procesada para train: 833
# imagen procesada para train: 834
# imagen procesada para train: 835
# imagen procesada para train: 836
# imagen procesada para train: 837
# imagen procesada para train: 838
# imagen procesada para train: 839
# imagen procesada para train: 840
# imagen procesada para train: 841
# imagen procesada para train: 842
# imagen procesada para train: 843
# imagen procesada para train: 844
# imagen procesada para train: 845
# imagen procesada para train: 846
# imagen procesada para train: 847
# imagen procesada para train: 848
# imagen procesada para train: 849
# imagen procesada para train: 850
# imagen procesada para train: 851
# imagen procesada para train: 852
# imagen procesada para train: 853
# imagen procesada para train: 854
# imagen procesada para train: 855
# imagen procesada para train: 856
# imagen procesada para train: 857
# imagen procesada para train: 858
# imagen procesada para train: 859
# imagen procesada para train: 860
# imagen procesada para train: 861
# imagen procesada para train: 862
# imagen procesada para train: 863
# imagen procesada para train: 864
# imagen procesada para train: 865
# imagen procesada para train: 866
# imagen procesada para train: 867
# imagen procesada para train: 868
# imagen procesada para train: 869
# imagen procesada para train: 870
# imagen procesada para train: 871
# imagen procesada para train: 872
# imagen procesada para train: 873
# imagen procesada para train: 874
# imagen procesada para train: 875
# imagen procesada para train: 876
# imagen procesada para train: 877
# imagen procesada para train: 878
# imagen procesada para train: 879
# imagen procesada para train: 880
# imagen procesada para train: 881
# imagen procesada para train: 882
# imagen procesada para train: 883
# imagen procesada para train: 884
# imagen procesada para train: 885

# %%
train_df.head(10)
# Out:
#                  Nombre      Xmin      Xmax      Ymin      Ymax   Label
# 0  000676e5fa045195.jpg  0.351875  0.386875  0.422500  0.445000  Person
# 1  000be572efea5716.jpg  0.000000  0.999375  0.274859  0.969043  Person
# 2  000fe11025f2e246.jpg  0.198750  0.277500  0.725455  0.938182  Person
# 3  000fe11025f2e246.jpg  0.246250  0.297500  0.707273  0.936364  Person
# 4  000fe11025f2e246.jpg  0.367500  0.467500  0.743636  0.989091  Person
# 5  000fe11025f2e246.jpg  0.423750  0.487500  0.738182  0.920000  Person
# 6  000fe11025f2e246.jpg  0.503750  0.551250  0.658182  0.794545  Person
# 7  000fe11025f2e246.jpg  0.503750  0.595000  0.794545  0.967273  Person
# 8  000fe11025f2e246.jpg  0.536250  0.561250  0.629091  0.687273  Person
# 9  000fe11025f2e246.jpg  0.547500  0.587500  0.623636  0.760000  Person

# %%
#Es claro que este valor sera mayor al numero de imagenes de la carpeta train
train_df.shape
# Out:
# (3809, 6)

# %%
#Realizando lo mismo para la carpeta de test.
test_df = pd.DataFrame(columns=['Nombre','Xmin','Xmax','Ymin', 'Ymax','Label'])

test_imgs = os.listdir(test_path)
c=0
for i in range(len(test_imgs)):
  sys.stdout.flush()
  c=c+1
  print("imagen procesada para test: {}".format(c))
  img_nombre = test_imgs[i]
  img_id=img_nombre[0:16]
  tmp_df = anota_box_pd[anota_box_pd['ImageID']==img_id]
  for index, row in tmp_df.iterrows():
    labelName = row['LabelName']
    for i in range(len(etiquetas)):
      if labelName == etiquetas[i]:
        test_df = test_df.append({'Nombre':img_nombre,
                                    'Xmin':row['XMin'],
                                    'Xmax':row['XMax'],
                                    'Ymin':row['YMin'],
                                    'Ymax':row['YMax'],
                                    'Label':clas[i]},
                                   ignore_index=True)
# Out:
# imagen procesada para test: 1
# imagen procesada para test: 2
# imagen procesada para test: 3
# imagen procesada para test: 4
# imagen procesada para test: 5
# imagen procesada para test: 6
# imagen procesada para test: 7
# imagen procesada para test: 8
# imagen procesada para test: 9
# imagen procesada para test: 10
# imagen procesada para test: 11
# imagen procesada para test: 12
# imagen procesada para test: 13
# imagen procesada para test: 14
# imagen procesada para test: 15
# imagen procesada para test: 16
# imagen procesada para test: 17
# imagen procesada para test: 18
# imagen procesada para test: 19
# imagen procesada para test: 20
# imagen procesada para test: 21
# imagen procesada para test: 22
# imagen procesada para test: 23
# imagen procesada para test: 24
# imagen procesada para test: 25
# imagen procesada para test: 26
# imagen procesada para test: 27
# imagen procesada para test: 28
# imagen procesada para test: 29
# imagen procesada para test: 30
# imagen procesada para test: 31
# imagen procesada para test: 32
# imagen procesada para test: 33
# imagen procesada para test: 34
# imagen procesada para test: 35
# imagen procesada para test: 36
# imagen procesada para test: 37
# imagen procesada para test: 38
# imagen procesada para test: 39
# imagen procesada para test: 40
# imagen procesada para test: 41
# imagen procesada para test: 42
# imagen procesada para test: 43
# imagen procesada para test: 44
# imagen procesada para test: 45
# imagen procesada para test: 46
# imagen procesada para test: 47
# imagen procesada para test: 48
# imagen procesada para test: 49
# imagen procesada para test: 50
# imagen procesada para test: 51
# imagen procesada para test: 52
# imagen procesada para test: 53
# imagen procesada para test: 54
# imagen procesada para test: 55
# imagen procesada para test: 56
# imagen procesada para test: 57
# imagen procesada para test: 58
# imagen procesada para test: 59
# imagen procesada para test: 60
# imagen procesada para test: 61
# imagen procesada para test: 62
# imagen procesada para test: 63
# imagen procesada para test: 64
# imagen procesada para test: 65
# imagen procesada para test: 66
# imagen procesada para test: 67
# imagen procesada para test: 68
# imagen procesada para test: 69
# imagen procesada para test: 70
# imagen procesada para test: 71
# imagen procesada para test: 72
# imagen procesada para test: 73
# imagen procesada para test: 74
# imagen procesada para test: 75
# imagen procesada para test: 76
# imagen procesada para test: 77
# imagen procesada para test: 78
# imagen procesada para test: 79
# imagen procesada para test: 80
# imagen procesada para test: 81
# imagen procesada para test: 82
# imagen procesada para test: 83
# imagen procesada para test: 84
# imagen procesada para test: 85
# imagen procesada para test: 86
# imagen procesada para test: 87
# imagen procesada para test: 88
# imagen procesada para test: 89
# imagen procesada para test: 90
# imagen procesada para test: 91
# imagen procesada para test: 92
# imagen procesada para test: 93
# imagen procesada para test: 94
# imagen procesada para test: 95
# imagen procesada para test: 96
# imagen procesada para test: 97
# imagen procesada para test: 98
# imagen procesada para test: 99
# imagen procesada para test: 100
# imagen procesada para test: 101
# imagen procesada para test: 102
# imagen procesada para test: 103
# imagen procesada para test: 104
# imagen procesada para test: 105
# imagen procesada para test: 106
# imagen procesada para test: 107
# imagen procesada para test: 108
# imagen procesada para test: 109
# imagen procesada para test: 110
# imagen procesada para test: 111
# imagen procesada para test: 112
# imagen procesada para test: 113
# imagen procesada para test: 114
# imagen procesada para test: 115
# imagen procesada para test: 116
# imagen procesada para test: 117
# imagen procesada para test: 118
# imagen procesada para test: 119
# imagen procesada para test: 120
# imagen procesada para test: 121
# imagen procesada para test: 122
# imagen procesada para test: 123
# imagen procesada para test: 124
# imagen procesada para test: 125
# imagen procesada para test: 126
# imagen procesada para test: 127
# imagen procesada para test: 128
# imagen procesada para test: 129
# imagen procesada para test: 130
# imagen procesada para test: 131
# imagen procesada para test: 132
# imagen procesada para test: 133
# imagen procesada para test: 134
# imagen procesada para test: 135
# imagen procesada para test: 136
# imagen procesada para test: 137
# imagen procesada para test: 138
# imagen procesada para test: 139
# imagen procesada para test: 140
# imagen procesada para test: 141
# imagen procesada para test: 142
# imagen procesada para test: 143
# imagen procesada para test: 144
# imagen procesada para test: 145
# imagen procesada para test: 146
# imagen procesada para test: 147
# imagen procesada para test: 148
# imagen procesada para test: 149
# imagen procesada para test: 150
# imagen procesada para test: 151
# imagen procesada para test: 152
# imagen procesada para test: 153
# imagen procesada para test: 154
# imagen procesada para test: 155
# imagen procesada para test: 156
# imagen procesada para test: 157
# imagen procesada para test: 158
# imagen procesada para test: 159
# imagen procesada para test: 160
# imagen procesada para test: 161
# imagen procesada para test: 162
# imagen procesada para test: 163
# imagen procesada para test: 164
# imagen procesada para test: 165
# imagen procesada para test: 166
# imagen procesada para test: 167
# imagen procesada para test: 168
# imagen procesada para test: 169
# imagen procesada para test: 170
# imagen procesada para test: 171
# imagen procesada para test: 172
# imagen procesada para test: 173
# imagen procesada para test: 174
# imagen procesada para test: 175
# imagen procesada para test: 176
# imagen procesada para test: 177
# imagen procesada para test: 178
# imagen procesada para test: 179
# imagen procesada para test: 180
# imagen procesada para test: 181
# imagen procesada para test: 182

# %%
#convirtiendo los dataframes creados a archivos CSV.
train_df.to_csv('train.csv')
test_df.to_csv('test.csv')

# %%
"""Este codigo nos sirve para crear un archivo texto donde estara la informacion
de cada imagen de entrenamiento con sus datos de bbox y etiqueta.
Observe como cada linea es un bbox diferente. El archivo de imagen se puede repetir
tantas veces como bbox tenga la imagen."""
train_df = pd.read_csv('train.csv')
with open("D:/Universidad/Computer_Vision_UAO/Proyecto_de_curso_CVwDP/od_distanciamiento_social/keras-retinanet/entrenamiento1000.txt", 'w+') as f:
  for idx, row in train_df.iterrows():
    img = cv2.imread(train_path+ row['Nombre'])
    h,w = img.shape[:2]
    x1 = int(row['Xmin']*w)
    x2 = int(row['Xmax']*w)
    y1 = int(row['Ymin']*h)
    y2 = int(row['Ymax']*h)
    archivo = os.path.join(train_path,row['Nombre'])
    label = row['Label']
    f.write(archivo + ',' + str(x1) + ',' + str(y1) + ',' + str(x2) + ',' + str(y2) + ',' + label + '\n')

# %%
#Igualmente para el archivo test.

test_df = pd.read_csv('test.csv')
with open("D:/Universidad/Computer_Vision_UAO/Proyecto_de_curso_CVwDP/od_distanciamiento_social/keras-retinanet/test1000.txt", 'w+') as f:
  for idx, row in test_df.iterrows():
    img = cv2.imread(test_path+ row['Nombre'])
    h,w = img.shape[:2]
    x1 = int(row['Xmin']*w)
    x2 = int(row['Xmax']*w)
    y1 = int(row['Ymin']*h)
    y2 = int(row['Ymax']*h)
    archivo = os.path.join(test_path,row['Nombre'])
    label = row['Label']
    f.write(archivo + ',' + str(x1) + ',' + str(y1) + ',' + str(x2) + ',' + str(y2) + ',' + label + '\n')

# %% [markdown]
# **FIN!!!!.
# Revise en su drive y compruebe que exista una carpeta llamada FasterRCNN y dentro de ella los dos archivos de texto (test y train), tambien deberá estar una subcarpeta llamada dataset y dentro de esta dos subcarpetas: train que contiene todas las imagenes fisicas de entrenamiento, y test, que contiene las iamgenes fisicas de prueba o validacion.**
